# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Built in dataset

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Distribution plot/Histogram ---- univariable

# %% [markdown]
# Types
# 1. distplot -- univariant
# 2. jointplot -- bivariant --- many kind of plots
# 3. pairplot -- show all types of plots for all cols
# 4. rugplot -- bin size is 0
# 5. kdeplot -- only kde

# %%
sns.distplot(df['total_bill'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# kde = kernel density estimator in y axis
# helps to find probability density function

# %%
sns.displot(df['total_bill'], kde = False, bins = 20) #normal histogram

# %% [markdown]
# # jointplot === default scatter plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'hex') #hexagon plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'reg') #regression plot

# %%
sns.pairplot(df)
#automatically pairs any 2 cols in a dataset.......... used only for min no, of columns
#only numerical

# %%
sns.pairplot(df, hue = 'sex') #mention in hue for categorical variables

# %% [markdown]
# ## Rugplot

# %%
sns.rugplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# ## KDE plot

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(df['total_bill'])
sns.kdeplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Caterogiacal plots

# %% [markdown]
# Types
# 1. Bar
# 2. factor
# 3. box
# 4. violin
# 5. stripplot
# 6. swarmplot
# 7. count

# %%
sns.barplot(x= 'sex', y = 'total_bill', data = df) #barplot--- show mean
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(x= 'sex', y = 'total_bill', data = df, estimator = np.std) #standaer deviation
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Count plot --- default y-axis == count

# %%
sns.countplot(x = 'sex', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box plot -- to find outlier

# %%
sns.boxplot(x='sex',y='total_bill',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data = df) # for whole data
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = df, orient = 'h') #horizontal
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='sex',y='total_bill',data = df, hue = 'smoker') #hue == classifier
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Violin plot -- can able to see graph distribution

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = df, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = df, hue = 'sex', split = True) #default split = false
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## stripplot --- one variable will be categorical

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = df, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = df, hue = 'sex', dodge = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = df, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = df, dodge = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Factor plot --- take kind / changed to catplot

# %%
sns.factorplot(x = 'sex', y = 'total_bill', data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.catplot(x = 'sex', y = 'total_bill', data = df, kind = 'bar')

# %% [markdown]
# # Matrix plot

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Heat map -- mostly used
# need one number column

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(), annot = True) #to show values
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
flights.pivot_table(values='passengers', index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers', index='month',columns='year'))
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# # Matrix plots

# %% [markdown]
# ## Pair grid

# %%
import matplotlib.pyplot as plt
a = sns.PairGrid(iris)
a.map(plt.scatter)

# %%
a = sns.PairGrid(iris)
a.map_diag(plt.scatter)
a.map_upper(plt.hist)
a.map_lower(sns.bar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18136\1503784079.py in <module>
#       1 a = sns.PairGrid(iris)
# ----> 2 a.map_diag(plt.scatter)
#       3 a.map_upper(plt.hist)
#       4 a.map_lower(sns.bar)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1448
#    1449         if "hue" not in signature(func).parameters:
# -> 1450             return self._map_diag_iter_hue(func, **kwargs)
#    1451
#    1452         # Loop over diagonal variables and axes, making one plot in each
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _map_diag_iter_hue(self, func, **kwargs)
#    1515                     func(x=data_k, label=label_k, color=color, **plot_kwargs)
#    1516                 else:
# ...

# %%
sns.pairplot(iris) #default diagonal -- hist other -- scatter

# %%
sns.pairplot(iris, hue = 'species')

# %% [markdown]
# ## Facet

# %%
g = sns.FacetGrid('tips', col = 'time', row = 'smoker', hue = 'sex')
gmmap(plt.hist, 'total_bill')

# %% [markdown]
# # Regression plot

# %%
sns.lmplot(x='total_bill', y='tip', data = df)

# %%
sns.lmplot(x='total_bill', y='tip', data = df, hue = 'sex')

# %%
sns.lmplot(x='total_bill', y='tip', data = df, hue = 'sex', palette = 'rainbow')

# %% [markdown]
# # Working with markers

# %%
sns.lmplot(x='total_bill', y='tip', data = df, hue = 'sex', palette = 'rainbow', markers = ['o','^'])

# %% [markdown]
# ## Using Grid

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, row='day')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='time', aspect =0.8, size = 2) #to change size

# %% [markdown]
# # Set style

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'sex', data = df)

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'sex', data = df)

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'sex', data = df)
sns.despine()

# %% [markdown]
# # Relational plots
# used when x ais and y axis parameters have arelation b/w them

# %%
sns.relplot(x='total_bill', y='tip', data = df, kind = 'line', col = 'sex')

# %%
sns.relplot(x='total_bill', y='tip', data = df, kind = 'line', row = 'sex')
